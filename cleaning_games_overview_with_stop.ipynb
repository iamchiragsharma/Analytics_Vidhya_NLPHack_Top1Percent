# %%
import numpy as np
import pandas as pd
import data_utils
import re
import spacy
from tqdm import tqdm
import string
import ast

# %%
"""Notebook to clean data:
* Train
* Overview
* Test
It doesnot remove stop words. Removes non ascii chars"""
# Out:
# 'Notebook to clean data:\n* Train\n* Overview\n* Test\nIt doesnot remove stop words. Removes non ascii chars'

# %%
from collections import Counter
import matplotlib.pyplot as plt
nlp = spacy.load("en_core_web_sm")
len(nlp.Defaults.stop_words)
# Out:
# 326

# %%
stop_words = nlp.Defaults.stop_words

# %%
train = pd.read_csv("train_data/train.csv")
overview = pd.read_csv("train_data/game_overview.csv")
corpus = list(train['user_review'].values) + list(overview['overview'].values)

# %%
print("Train Data Shape ",train.shape)
print("Overview Shape ", overview.shape)
print("17494 + 64 = ", len(corpus))
# Out:
# Train Data Shape  (17494, 5)
# Overview Shape  (64, 5)
# 17494 + 64 =  17558

# %%
print("CORPUS LENGTH : ", str(len(corpus)))
# Out:
# CORPUS LENGTH :  17558

# %%
text_sent = [data_utils.expand_contractions(sent) for sent in corpus]
text_sent = [data_utils.remove_accented_chars(sent) for sent in text_sent]
text_sent = [re.sub("[-!\"#$%&'()*+,./:;<=>?@\][^_`|}{~']"," ",text) for text in text_sent]
text_sent = [text.replace("\\"," ") for text in text_sent]
text_sent = [re.sub(r'\s+', ' ',sent) for sent in text_sent] #Removing extra spaces but won't clean front of the row
text_sent = list(map(str.lower,text_sent))
text_sent[0]
# Out:
# 'i am scared and hearing creepy voices so i will pause for a moment and write a review while i wait for my heart beat to return to atleast somewhat calmer times this game is adorable and creepy like my happy tree friends but with the graphics sceme of my childhood but more bubble and clean hello 1990s what charactes there are that isnot trying to kill me were likable and a bit odd i did do a few noob things though such as oh look a class room full of ghosts from dead children lets shine my flashlight on them and stand there staring at them or hmm creepy music i will turn around and see if i can see what is chasing me never before in a game have i been this afraid of finding a locked door '

# %%
#Let's check the words with punctuation in them
punctuations = set(string.punctuation)
words_with_punctuation = list(filter(lambda x: set(x).intersection(punctuations), list(map(lambda x:x[0], words_counter.most_common()))))
len(words_with_punctuation) #Count of words having punctuation in them
words_with_punctuation
# Out:
# []

# %%
#Creating word count for further operations
words = [t for text in text_sent for t in text.split()]
words_counter = Counter(words)

# %%
words_count = list(map(lambda x:x[1], words_counter.most_common()[::-1]))
words_count_counter = Counter(words_count)
words_count_counter.most_common(10) #words that have appeared only once and the count of such words -> words that have occured
#only 1 time have occured 93k times
# Out:
# [(1, 30813),
#  (2, 6362),
#  (3, 3021),
#  (4, 1830),
#  (5, 1243),
#  (6, 897),
#  (7, 740),
#  (8, 566),
#  (9, 521),
#  (10, 462)]

# %%
docs = nlp.pipe(text_sent)

# %%
cleaned_text = []
pbar = tqdm(total=len(text_sent))
for i,doc in enumerate(docs):
    tokens = []
    for token in doc:
        if token.like_url or token.like_email:
            pass
        else:
            tokens.append(token.text)
    cleaned_text.append(tokens)
    if i%500 == 0 and i != 0:
        pbar.update(500)
pbar.close()
# Out:
# 100%|█████████▉| 17500/17558 [05:07<00:01, 56.94it/s]

# %%
train.head()
# Out:
#    review_id                        title    year  \
# 0          1  Spooky's Jump Scare Mansion  2016.0
# 1          2  Spooky's Jump Scare Mansion  2016.0
# 2          3  Spooky's Jump Scare Mansion  2016.0
# 3          4  Spooky's Jump Scare Mansion  2015.0
# 4          5  Spooky's Jump Scare Mansion  2015.0
#
#                                          user_review  user_suggestion
# 0  I'm scared and hearing creepy voices.  So I'll...                1
# 1  Best game, more better than Sam Pepper's YouTu...                1
# 2  A littly iffy on the controls, but once you kn...                1
# 3  Great game, fun and colorful and all that.A si...                1
# 4  Not many games have the cute tag right next to...                1

# %%
cleaned_train = train.copy()
cleaned_overview = overview.copy()

# %%
cleaned_train['user_review'] =  [" ".join(text) for text in cleaned_text][:-64]
cleaned_overview['overview'] = [" ".join(text) for text in cleaned_text][-64:]

# %%
cleaned_train.head()
# Out:
#    review_id                        title    year  \
# 0          1  Spooky's Jump Scare Mansion  2016.0
# 1          2  Spooky's Jump Scare Mansion  2016.0
# 2          3  Spooky's Jump Scare Mansion  2016.0
# 3          4  Spooky's Jump Scare Mansion  2015.0
# 4          5  Spooky's Jump Scare Mansion  2015.0
#
#                                          user_review  user_suggestion
# 0  i am scared and hearing creepy voices so i wil...                1
# 1  best game more better than sam peppers youtube...                1
# 2  a littly iffy on the controls but once you kno...                1
# 3  great game fun and colorful and all that a sid...                1
# 4  not many games have the cute tag right next to...                1

# %%
#Let's cleans tags as well
# tags = cleaned_overview['tags'].values
# tags = [ast.literal_eval(tag) for tag in tags]
# tags = [" ".join(tag) for tag in tags]
# cleaned_overview['tags'] = tags

# %%
cleaned_overview.head()
# Out:
#                               title                          developer  \
# 0       Spooky's Jump Scare Mansion                       Lag Studios
# 1                    Sakura Clicker                      Winged Cloud
# 2                           WARMODE                           WARTEAM
# 3                   Fractured Space              Edge Case Games Ltd.
# 4  Counter-Strike: Global Offensive  Valve, Hidden Path Entertainment
#
#                publisher                                               tags  \
# 0           Lag Studios   Horror Free to Play Cute First-Person Singlepl...
# 1          Winged Cloud   Nudity Anime Free to Play Mature Sexual Conten...
# 2               WARTEAM   Early Access Free to Play FPS Multiplayer Shoo...
# 3  Edge Case Games Ltd.   Space Multiplayer Free to Play PvP MOBA Action...
# 4                 Valve   FPS Multiplayer Shooter Action Team-Based Comp...
#
#                                             overview
# 0  can you survive 1000 rooms of cute terror or w...
# 1  the latest entry in the sakura series is more ...
# 2  free to play shooter about the confrontation o...
# 3  take the helm of a gigantic capital ship and g...
# 4  counter strike global offensive cs go expands ...

# %%
games_data = pd.merge(cleaned_train,cleaned_overview,left_on='title',right_on='title')
games_data.to_csv("proper_cleaned_data/clean_review_tags_overview_notremoved_stopwords_frequent_nonfrequent_words.csv",index=False)

# %%
games_data.head()
# Out:
#    review_id                        title    year  \
# 0          1  Spooky's Jump Scare Mansion  2016.0
# 1          2  Spooky's Jump Scare Mansion  2016.0
# 2          3  Spooky's Jump Scare Mansion  2016.0
# 3          4  Spooky's Jump Scare Mansion  2015.0
# 4          5  Spooky's Jump Scare Mansion  2015.0
#
#                                          user_review  user_suggestion  \
# 0  i am scared and hearing creepy voices so i wil...                1
# 1  best game more better than sam peppers youtube...                1
# 2  a littly iffy on the controls but once you kno...                1
# 3  great game fun and colorful and all that a sid...                1
# 4  not many games have the cute tag right next to...                1
#
#       developer     publisher  \
# 0  Lag Studios   Lag Studios
# 1  Lag Studios   Lag Studios
# 2  Lag Studios   Lag Studios
# 3  Lag Studios   Lag Studios
# 4  Lag Studios   Lag Studios
#
#                                                 tags  \
# 0  Horror Free to Play Cute First-Person Singlepl...
# 1  Horror Free to Play Cute First-Person Singlepl...
# 2  Horror Free to Play Cute First-Person Singlepl...
# 3  Horror Free to Play Cute First-Person Singlepl...
# 4  Horror Free to Play Cute First-Person Singlepl...
#
#                                             overview
# 0  can you survive 1000 rooms of cute terror or w...
# 1  can you survive 1000 rooms of cute terror or w...
# 2  can you survive 1000 rooms of cute terror or w...
# 3  can you survive 1000 rooms of cute terror or w...
# 4  can you survive 1000 rooms of cute terror or w...

# %%
games_data[games_data['user_review']== '']
# Out:
#        review_id                        title    year user_review  \
# 215          216  Spooky's Jump Scare Mansion  2017.0
# 1672   Free to Play MOBA Strategy Multiplayer Team-Ba...
# 1729   Free to Play MOBA Strategy Multiplayer Team-Ba...
# 1899   Free to Play MOBA Strategy Multiplayer Team-Ba...
# 3662   Free to Play Multiplayer FPS Action Shooter Cl...
# 3869   Free to Play Multiplayer FPS Action Shooter Cl...
# 5587   Tanks Free to Play Multiplayer Action World Wa...
# 5860   Simulation Flight Free to Play Military Multip...
# 6414   Free to Play World War II Multiplayer FPS War ...
# 6430   Free to Play World War II Multiplayer FPS War ...
# 7189   Free to Play Card Game Multiplayer Strategy Tr...
# 8926   Free to Play Massively Multiplayer FPS Shooter...
# 9209   Free to Play Massively Multiplayer FPS Shooter...
# 15302  Free to Play Board Game Strategy Massively Mul...
# 16568  Free to Play Tower Defense Multiplayer Strateg...
#
#                                                 overview
# 190    can you survive 1000 rooms of cute terror or w...
# 438    the latest entry in the sakura series is more ...
# 1672   the most played game on steam every day millio...
# 1729   the most played game on steam every day millio...
# 1899   the most played game on steam every day millio...
# 3662     the most fun you can have online pc gameris ...
# 3869     the most fun you can have online pc gameris ...
# 5587   world of tanks blitz is a cross platform free ...
# 5860   feel the excitement of flying the su 25 t frog...
# 6414   heroes generals is a full on all out war exper...
# 6430   heroes generals is a full on all out war exper...
# 7189   play on your ownstory mode provides hours of s...
# 8926   planetside 2 is a free to play massively multi...
# 9209   planetside 2 is a free to play massively multi...
# 15302    business tour simple and entertaining gamepl...
# 16568  play the top rated tower defense franchise in ...

# %% [markdown]
# ## Test Cleaning

# %%
def test_cleaning(df):
    overview = pd.read_csv("train_data/game_overview.csv")
    corpus = list(df['user_review'].values) + list(overview['overview'].values)
    print("File Data Shape ",df.shape)
    print("Overview Shape ", overview.shape)
    print("CORPUS LENGTH : ", str(len(corpus)))
    text_sent = [data_utils.expand_contractions(sent) for sent in corpus]
    text_sent = [data_utils.remove_accented_chars(sent) for sent in text_sent]
    text_sent = [re.sub("[-!\"#$%&'()*+,./:;<=>?@\][^_`|}{~']"," ",text) for text in text_sent]
    text_sent = [text.replace("\\"," ") for text in text_sent]
    text_sent = [re.sub(r'\s+', ' ',sent) for sent in text_sent] #Removing extra spaces but won't clean front of the row
    text_sent = list(map(str.lower,text_sent))
    
    docs = nlp.pipe(text_sent)
    
    cleaned_text = []
    pbar = tqdm(total=len(text_sent))
    for i,doc in enumerate(docs):
        tokens = []
        for token in doc:
            if token.like_url or token.like_email:
                pass
            else:
                tokens.append(token.text)
        cleaned_text.append(tokens)
        if i%500 == 0 and i != 0:
            pbar.update(500)
    pbar.close()
    
    df['user_review'] =  [" ".join(text) for text in cleaned_text][:-64]
    overview['overview'] = [" ".join(text) for text in cleaned_text][-64:]
    df_data = pd.merge(df,overview,left_on='title',right_on='title')
    df_data.to_csv("proper_cleaned_data/test_clean_review_tags_overview_notremoved_stopwords_frequent_nonfrequent_words.csv",index=False)

# %%
df = pd.read_csv("test_data/test.csv")
test_cleaning(df)
# Out:
# File Data Shape  (8045, 4)
# Overview Shape  (64, 5)
# CORPUS LENGTH :  8109
#  99%|█████████▊| 8000/8109 [01:49<00:01, 73.13it/s]

# %%
train = pd.read_csv("proper_cleaned_data/clean_review_tags_overview_notremoved_stopwords_frequent_nonfrequent_words.csv")
